# %%
from zigzag.classes.stages import *
from stream.classes.stages import *
from stream.visualization.schedule import (
    plot_timeline_brokenaxes,
)
from stream.visualization.memory_usage import plot_memory_usage
from stream.inputs.examples.hardware.cores.TPU_like import get_core as get_tpu_core
from stream.inputs.examples.hardware.cores.offchip import get_offchip_core
from stream.inputs.examples.hardware.nocs.mesh_2d import get_2d_mesh
from zigzag.classes.hardware.architecture.accelerator import Accelerator
from zigzag.classes.stages import Stage
from stream.classes.workload.computation_node import ComputationNode
from stream.classes.workload.simd_node import SimdNode
from stream.classes.workload.elementwise_node import ElementwiseNode
from stream.classes.workload.flatten_node import FlattenNode
from stream.classes.workload.dummy_node import DummyNode
from stream.classes.stages import UserDefinedModelParserStage
import pickle
from cyclic_scheduling_dse.stream_compatibility_layer import CyclicFitnessEvaluatorBuilder, MinimumLatency, MinimumMemory

# %%
import os
os.environ["BENCHMARK"] = "0"

# %% [markdown]
# ## Fsrcnn

# %%
#import logging as _logging

#_logging_level = _logging.INFO
#_logging_format = (
#    "%(asctime)s - %(name)s.%(funcName)s +%(lineno)s - %(levelname)s - %(message)s"
#)
#_logging.basicConfig(level=_logging_level, format=_logging_format)


mainstage = MainStage(
    [  # Initializes the MainStage as entry point
        AcceleratorParserStage,  # Parses the accelerator
        StreamONNXModelParserStage,  # Parses the ONNX Model into the workload
        GenerateCNWorkloadHybridStage,
        IntraCoreMappingStage,
        InterCoreMappingStage,
    ],
    accelerator="architecture.eyeriss_tpu",  # required by AcceleratorParserStage
    workload_path="./problems/fsrcnn.onnx",  # required by ModelParserStage
    mapping_path="mapping.super_resolution_mapping",
    cn_define_mode=1,
    hint_loops=[("OX", "all")],
    loma_lpf_limit=2,
    nb_ga_generations = 1,
    nb_ga_individuals = 2,
    plot_hof=True,
    plot_file_name='plot.png',
    operands_to_prefetch = [],
    custom_fitness_evaluator=CyclicFitnessEvaluatorBuilder(
        sdf_relation="OX",
        optimization_type=MinimumMemory(),
    ),
)

[(scme, _), *_] = mainstage.run()

plot_timeline_brokenaxes(
    scme,
    False,
    section_start_percent=(0,97),
    percent_shown=(3,3),
    plot_data_transfer=True,
    fig_path="/tmp/timeline",
)

plot_memory_usage(scme, (0,97), (3,3), fig_path="/tmp/memory")
# Out:
# {'O': Tensor(0, 0, 'O'), 'W': Tensor(0, 0, 'W'), 'I': Tensor(0, 0, 'I')}
# {'O': Tensor(1, 0, 'O'), 'W': Tensor(1, 0, 'W'), 'I': Tensor(1, 0, 'I')}
# {'O': Tensor(2, 0, 'O'), 'W': Tensor(2, 0, 'W'), 'I': Tensor(2, 0, 'I')}
# {'O': Tensor(3, 0, 'O'), 'W': Tensor(3, 0, 'W'), 'I': Tensor(3, 0, 'I')}
# {'O': Tensor(4, 0, 'O'), 'W': Tensor(4, 0, 'W'), 'I': Tensor(4, 0, 'I')}
# {'O': Tensor(5, 0, 'O'), 'W': Tensor(5, 0, 'W'), 'I': Tensor(5, 0, 'I')}
# {'O': Tensor(6, 0, 'O'), 'W': Tensor(6, 0, 'W'), 'I': Tensor(6, 0, 'I')}
# {'O': Tensor(7, 0, 'O'), 'W': Tensor(7, 0, 'W'), 'I': Tensor(7, 0, 'I')}
# HI...False
# Set parameter Username
# Academic license - for non-commercial use only - expires 2024-07-23
# Gurobi Optimizer version 10.0.2 build v10.0.2rc0 (linux64)
#
# CPU model: Intel(R) Core(TM) i7-10750H CPU @ 2.60GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 113 rows, 62 columns and 330 nonzeros
# Model fingerprint: 0x9134570e
# Variable types: 30 continuous, 32 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+09]
#   Objective range  [1e+00, 2e+05]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 2e+00]
# Warning: Model contains large matrix coefficients
#          Consider reformulating model or setting NumericFocus parameter
#          to avoid numerical issues.
#
# ---------------------------------------------------------------------------
# Multi-objectives: starting optimization with 2 objectives ...
# ---------------------------------------------------------------------------
#
# Multi-objectives: applying initial presolve ...
# ---------------------------------------------------------------------------
#
# Presolve removed 22 rows and 0 columns
# Presolve time: 0.00s
# Presolved: 91 rows and 62 columns
# ---------------------------------------------------------------------------
#
# Multi-objectives: optimize objective 1 (buffer_size) ...
# ---------------------------------------------------------------------------
#
# Presolve removed 29 rows and 15 columns
# Presolve time: 0.00s
# Presolved: 62 rows, 47 columns, 174 nonzeros
# Variable types: 15 continuous, 32 integer (0 binary)
#
# Root relaxation: objective 3.072000e+06, 22 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# H    0     0                    3072000.0000 3072000.00  0.00%     -    0s
#      0     0 3072000.00    0   14 3072000.00 3072000.00  0.00%     -    0s
#
# Explored 1 nodes (22 simplex iterations) in 0.02 seconds (0.00 work units)
# Thread count was 12 (of 12 available processors)
#
# Solution count 1: 3.072e+06
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.072000000000e+06, best bound 3.072000000000e+06, gap 0.0000%
# ---------------------------------------------------------------------------
#
# Multi-objectives: optimize objective 2 (throughput) ...
# ---------------------------------------------------------------------------
#
#
# Loaded user MIP start with objective -1e-09
#
# Presolve removed 27 rows and 14 columns
# Presolve time: 0.00s
# Presolved: 65 rows, 48 columns, 256 nonzeros
# Variable types: 16 continuous, 32 integer (0 binary)
#
# Root relaxation: objective -1.254941e-05, 44 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# H    0     0                      -0.0000125   -0.00001  0.00%     -    0s
#      0     0   -0.00001    0   23   -0.00001   -0.00001  0.00%     -    0s
#
# Explored 1 nodes (44 simplex iterations) in 0.03 seconds (0.00 work units)
# Thread count was 12 (of 12 available processors)
#
# Solution count 2: -1.25494e-05 -1e-09
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective -1.254941331493e-05, best bound -1.254941331493e-05, gap 0.0000%
#
# ---------------------------------------------------------------------------
# Multi-objectives: solved in 0.03 seconds (0.00 work units), solution count 2
#
# Cycle time:79685
# Total buffer size: 375.00 kB
# Saved memory usage fig to /tmp/memory

# %%
import logging as _logging

_logging_level = _logging.INFO
_logging_format = (
    "%(asctime)s - %(name)s.%(funcName)s +%(lineno)s - %(levelname)s - %(message)s"
)
_logging.basicConfig(level=_logging_level, format=_logging_format)


mainstage = MainStage(
    [  # Initializes the MainStage as entry point
        AcceleratorParserStage,  # Parses the accelerator
        UserDefinedModelParserStage,  # Parses the ONNX Model into the workload
        GenerateCNWorkloadHybridStage,
        IntraCoreMappingStage,
        InterCoreMappingStage,
    ],
    accelerator="architecture.eyeriss_tpu",  # required by AcceleratorParserStage
    workload_path="problems.mccnn",  # required by ModelParserStage
    mapping_path="mapping.mccnn_mapping",
    cn_define_mode=1,
    hint_loops=[("OY", "all")],
    loma_lpf_limit=2,
    nb_ga_generations = 1,
    nb_ga_individuals = 2,
    plot_hof=True,
    plot_file_name='plot.png',
    operands_to_prefetch = [],
    custom_fitness_evaluator=CyclicFitnessEvaluatorBuilder(
        sdf_relation="OY",
        optimization_type=MinimumMemory(),
    ),
)

[(scme, _), *_] = mainstage.run()

plot_timeline_brokenaxes(
    scme,
    False,
    section_start_percent=(0,97),
    percent_shown=(3,3),
    plot_data_transfer=True,
    fig_path="/tmp/timeline",
)

plot_memory_usage(scme, (0,97), (3,3), fig_path="/tmp/memory")
# Out:
# 2024-02-12 16:06:31,267 - zigzag.classes.io.accelerator.parser.parse_accelerator_from_path +52 - INFO - Parsed accelerator with cores [0, 1, 2].
# 2024-02-12 16:06:31,269 - stream.classes.workload.dnn_workload.__init__ +67 - INFO - Parsed layer node Conv_0 | INPUT ['the_first_input'] | OUTPUT ['Conv_0_output']
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[3], line 35
#       7 _logging.basicConfig(level=_logging_level, format=_logging_format)
#      10 mainstage = MainStage(
#      11     [  # Initializes the MainStage as entry point
#      12         AcceleratorParserStage,  # Parses the accelerator
#    (...)
#      32     ),
#      33 )
# ---> 35 [(scme, _), *_] = mainstage.run()
#      37 plot_timeline_brokenaxes(
#      38     scme,
#      39     False,
#    (...)
#      43     fig_path="/tmp/timeline",
#      44 )
#      46 plot_memory_usage(scme, (0,97), (3,3), fig_path="/tmp/memory")
#
# File ~/.local/lib/python3.10/site-packages/zigzag/classes/stages/Stage.py:49, in MainStage.run(self)
#      47 def run(self):
#      48     answers = []
# ---> 49     for cme, extra_info in self.list_of_callables[0](
#      50         self.list_of_callables[1:], **self.kwargs
#      51     ).run():
#      52         answers.append((cme, extra_info))
#      53     return answers
#
# File ~/.local/lib/python3.10/site-packages/zigzag/classes/stages/MainInputParserStages.py:21, in AcceleratorParserStage.run(self)
#      19 accelerator = self.accelerator_parser.get_accelerator()
#      20 sub_stage = self.list_of_callables[0](self.list_of_callables[1:], accelerator=accelerator, **self.kwargs)
# ---> 21 for cme, extra_info in sub_stage.run():
#      22     yield cme, extra_info
#
# File ~/.local/lib/python3.10/site-packages/stream/classes/stages/ModelParserStage.py:83, in UserDefinedModelParserStage.run(self)
#      82 def run(self) -> Generator:
# ---> 83     workload = parse_workload_from_path(
#      84         self.workload_path, self.mapping_path, self.accelerator
#      85     )
#      87     self.kwargs["accelerator"] = self.accelerator
#      88     sub_stage = self.list_of_callables[0](
#      89         self.list_of_callables[1:], workload=workload, **self.kwargs
#      90     )
#
# File ~/.local/lib/python3.10/site-packages/stream/classes/stages/ModelParserStage.py:65, in parse_workload_from_path(workload_path, mapping_path, accelerator)
#      62 module = importlib.import_module(mapping_path)
#      63 mapping = module.mapping
# ---> 65 workload = DNNWorkload(workload, mapping, accelerator)
#      66 logger.info(
#      67     f"Created workload graph with {workload.number_of_nodes()} nodes and {workload.number_of_edges()} edges."
#      68 )
#      70 return workload
#
# File ~/.local/lib/python3.10/site-packages/stream/classes/workload/dnn_workload.py:53, in DNNWorkload.__init__(self, workload, mapping, accelerator, **attr)
#      51 """For each item in the dict generate the LayerNode and add it to the dnn graph G"""
#      52 layer_name = layer["operator_type"] + "_" + str(layer_id)
# ---> 53 layer_input_names = [
#      54     l["operator_type"] + "_" + str(l_id) + "_output"
#      55     for (l_id, l) in workload_saved.items()
#      56     if l_id
#      57     in self.cat_lists_from_all_values_of_a_dict(layer["operand_source"])
#      58 ]
#      59 layer_output_names = [
#      60     layer["operator_type"] + "_" + str(layer_id) + "_output"
#      61 ]
#      63 if not layer_input_names:
#
# File ~/.local/lib/python3.10/site-packages/stream/classes/workload/dnn_workload.py:57, in <listcomp>(.0)
#      51 """For each item in the dict generate the LayerNode and add it to the dnn graph G"""
#      52 layer_name = layer["operator_type"] + "_" + str(layer_id)
#      53 layer_input_names = [
#      54     l["operator_type"] + "_" + str(l_id) + "_output"
#      55     for (l_id, l) in workload_saved.items()
#      56     if l_id
# ---> 57     in self.cat_lists_from_all_values_of_a_dict(layer["operand_source"])
#      58 ]
#      59 layer_output_names = [
#      60     layer["operator_type"] + "_" + str(layer_id) + "_output"
#      61 ]
#      63 if not layer_input_names:
#
# File ~/.local/lib/python3.10/site-packages/stream/classes/workload/dnn_workload.py:124, in DNNWorkload.cat_lists_from_all_values_of_a_dict(dict_to_cat)
#     122 li_ca = []
#     123 for li in dict_to_cat.values():
# --> 124     li_ca.extend(li)
#     125 return li_ca
#
# TypeError: 'ComputationNode' object is not iterable

# %%
ls work/
# Out:
# __pycache__/                      super_resolution_mapping.py
# resnet_mapping_3_convolutions.py  tpu_like_quad_core.py
# resnet_mapping.py

# %%
import os
os.environ["BENCHMARK"] = '0'

import logging as _logging

_logging_level = _logging.INFO
_logging_format = (
    "%(asctime)s - %(name)s.%(funcName)s +%(lineno)s - %(levelname)s - %(message)s"
)
_logging.basicConfig(level=_logging_level, format=_logging_format)


mainstage = MainStage(
    [  # Initializes the MainStage as entry point
        AcceleratorParserStage,  # Parses the accelerator
        StreamONNXModelParserStage,  # Parses the ONNX Model into the workload
        GenerateCNWorkloadHybridStage,
        IntraCoreMappingStage,
        InterCoreMappingStage,
    ],
    accelerator="architecture.TPU_like_quad_core",  # required by AcceleratorParserStage
    workload_path="./problems/resnet18_without_matmul.onnx",  # required by ModelParserStage
    mapping_path="mapping.tpu_like_quad_core",
    cn_define_mode=1,
    hint_loops=[("OX", "all")],
    loma_lpf_limit=2,
    nb_ga_generations = 5,
    nb_ga_individuals = 5,
    plot_hof=True,
    plot_file_name='plot.png',
    scheduler_candidate_selection = 'latency',
    operands_to_prefetch = [],
    custom_fitness_evaluator=CyclicFitnessEvaluatorBuilder(
        sdf_relation="OX",
    ),
)

[(scme, _), *_] = mainstage.run()

plot_timeline_brokenaxes(
    scme,
    False,
    section_start_percent=(0,),
    percent_shown=(3,),
    plot_data_transfer=True,
    fig_path="/tmp/timeline",
)

plot_memory_usage(scme, (0,), (3,), fig_path="/tmp/memory")
# Out:
# 2024-02-12 15:50:35,877 - zigzag.classes.io.accelerator.parser.parse_accelerator_from_path +52 - INFO - Parsed accelerator with cores [0, 2, 1, 3, 4, 5, 6].
# 2024-02-12 15:50:35,879 - stream.classes.io.onnx.model.parse_workload_from_onnx_model_and_mapping +92 - INFO - Parsed Conv node /conv1/Conv.
# 2024-02-12 15:50:35,882 - stream.classes.io.onnx.model.parse_workload_from_onnx_model_and_mapping +165 - INFO - Parsed Relu node /relu/Relu. as a DummyNode
# 2024-02-12 15:50:35,883 - stream.classes.io.onnx.model.parse_workload_from_onnx_model_and_mapping +127 - INFO - Parsed Pooling node /maxpool/MaxPool.
# 2024-02-12 15:50:35,883 - stream.classes.io.onnx.model.parse_workload_from_onnx_model_and_mapping +92 - INFO - Parsed Conv node /layer1/layer1.0/conv1/Conv.
# 2024-02-12 15:50:35,884 - stream.classes.io.onnx.model.parse_workload_from_onnx_model_and_mapping +165 - INFO - Parsed Relu node /layer1/layer1.0/relu/Relu. as a DummyNode
# 2024-02-12 15:50:35,885 - stream.classes.io.onnx.model.parse_workload_from_onnx_model_and_mapping +92 - INFO - Parsed Conv node /layer1/layer1.0/conv2/Conv.
# 2024-02-12 15:50:35,886 - stream.classes.io.onnx.model.parse_workload_from_onnx_model_and_mapping +152 - INFO - Parsed Add node /layer1/layer1.0/Add.
# 2024-02-12 15:50:35,887 - stream.classes.io.onnx.model.parse_workload_from_onnx_model_and_mapping +165 - INFO - Parsed Relu node /layer1/layer1.0/relu_1/Relu. as a DummyNode
# 2024-02-12 15:50:35,887 - stream.classes.io.onnx.model.parse_workload_from_onnx_model_and_mapping +92 - INFO - Parsed Conv node /layer1/layer1.1/conv1/Conv.
# 2024-02-12 15:50:35,888 - stream.classes.io.onnx.model.parse_workload_from_onnx_model_and_mapping +165 - INFO - Parsed Relu node /layer1/layer1.1/relu/Relu. as a DummyNode
# 2024-02-12 15:50:35,889 - stream.classes.io.onnx.model.parse_workload_from_onnx_model_and_mapping +92 - INFO - Parsed Conv node /layer1/layer1.1/conv2/Conv.
# 2024-02-12 15:50:35,890 - stream.classes.io.onnx.model.parse_workload_from_onnx_model_and_mapping +152 - INFO - Parsed Add node /layer1/layer1.1/Add.
# 2024-02-12 15:50:35,944 - stream.classes.io.onnx.model.parse_workload_from_onnx_model_and_mapping +165 - INFO - Parsed Relu node /layer1/layer1.1/relu_1/Relu. as a DummyNode
# 2024-02-12 15:50:35,945 - stream.classes.io.onnx.model.parse_workload_from_onnx_model_and_mapping +92 - INFO - Parsed Conv node /layer2/layer2.0/conv1/Conv.
# 2024-02-12 15:50:35,946 - stream.classes.io.onnx.model.parse_workload_from_onnx_model_and_mapping +165 - INFO - Parsed Relu node /layer2/layer2.0/relu/Relu. as a DummyNode
# 2024-02-12 15:50:35,946 - stream.classes.io.onnx.model.parse_workload_from_onnx_model_and_mapping +92 - INFO - Parsed Conv node /layer2/layer2.0/conv2/Conv.
# 2024-02-12 15:50:35,947 - stream.classes.io.onnx.model.parse_workload_from_onnx_model_and_mapping +92 - INFO - Parsed Conv node /layer2/layer2.0/downsample/downsample.0/Conv.
# 2024-02-12 15:50:35,948 - stream.classes.io.onnx.model.parse_workload_from_onnx_model_and_mapping +152 - INFO - Parsed Add node /layer2/layer2.0/Add.
# 2024-02-12 15:50:35,949 - stream.classes.io.onnx.model.parse_workload_from_onnx_model_and_mapping +165 - INFO - Parsed Relu node /layer2/layer2.0/relu_1/Relu. as a DummyNode
# 2024-02-12 15:50:35,950 - stream.classes.io.onnx.model.parse_workload_from_onnx_model_and_mapping +92 - INFO - Parsed Conv node /layer2/layer2.1/conv1/Conv.
# 2024-02-12 15:50:35,951 - stream.classes.io.onnx.model.parse_workload_from_onnx_model_and_mapping +165 - INFO - Parsed Relu node /layer2/layer2.1/relu/Relu. as a DummyNode
# 2024-02-12 15:50:35,951 - stream.classes.io.onnx.model.parse_workload_from_onnx_model_and_mapping +92 - INFO - Parsed Conv node /layer2/layer2.1/conv2/Conv.
# 2024-02-12 15:50:35,952 - stream.classes.io.onnx.model.parse_workload_from_onnx_model_and_mapping +152 - INFO - Parsed Add node /layer2/layer2.1/Add.
# 2024-02-12 15:50:35,953 - stream.classes.io.onnx.model.parse_workload_from_onnx_model_and_mapping +165 - INFO - Parsed Relu node /layer2/layer2.1/relu_1/Relu. as a DummyNode
# 2024-02-12 15:50:35,953 - stream.classes.io.onnx.model.parse_workload_from_onnx_model_and_mapping +92 - INFO - Parsed Conv node /layer3/layer3.0/conv1/Conv.
# 2024-02-12 15:50:35,954 - stream.classes.io.onnx.model.parse_workload_from_onnx_model_and_mapping +165 - INFO - Parsed Relu node /layer3/layer3.0/relu/Relu. as a DummyNode
# 2024-02-12 15:50:35,955 - stream.classes.io.onnx.model.parse_workload_from_onnx_model_and_mapping +92 - INFO - Parsed Conv node /layer3/layer3.0/conv2/Conv.
# 2024-02-12 15:50:35,956 - stream.classes.io.onnx.model.parse_workload_from_onnx_model_and_mapping +92 - INFO - Parsed Conv node /layer3/layer3.0/downsample/downsample.0/Conv.
# 2024-02-12 15:50:35,956 - stream.classes.io.onnx.model.parse_workload_from_onnx_model_and_mapping +152 - INFO - Parsed Add node /layer3/layer3.0/Add.
# 2024-02-12 15:50:35,957 - stream.classes.io.onnx.model.parse_workload_from_onnx_model_and_mapping +170 - INFO - Created ONNXWorkload graph with 29 nodes and 33 edges.
# 2024-02-12 15:50:36,006 - stream.classes.stages.GenerateCNWorkloadHybridStage.run +89 - INFO - ComputationNode(0,): Outer loops [TemporalLoop(OX,112)].
# 2024-02-12 15:50:36,006 - stream.classes.stages.GenerateCNWorkloadHybridStage.run +90 - INFO - ComputationNode(0,): Generated 112 finer nodes.
# 2024-02-12 15:50:36,021 - stream.classes.stages.GenerateCNWorkloadHybridStage.run +89 - INFO - ComputationNode(2,): Outer loops [TemporalLoop(OX,56)].
# 2024-02-12 15:50:36,022 - stream.classes.stages.GenerateCNWorkloadHybridStage.run +90 - INFO - ComputationNode(2,): Generated 56 finer nodes.
# 2024-02-12 15:50:36,038 - stream.classes.stages.GenerateCNWorkloadHybridStage.run +89 - INFO - ComputationNode(3,): Outer loops [TemporalLoop(OX,56)].
# 2024-02-12 15:50:36,038 - stream.classes.stages.GenerateCNWorkloadHybridStage.run +90 - INFO - ComputationNode(3,): Generated 56 finer nodes.
# 2024-02-12 15:50:36,054 - stream.classes.stages.GenerateCNWorkloadHybridStage.run +89 - INFO - ComputationNode(5,): Outer loops [TemporalLoop(OX,56)].
# 2024-02-12 15:50:36,054 - stream.classes.stages.GenerateCNWorkloadHybridStage.run +90 - INFO - ComputationNode(5,): Generated 56 finer nodes.
# 2024-02-12 15:50:36,068 - stream.classes.stages.GenerateCNWorkloadHybridStage.run +89 - INFO - ComputationNode(6,): Outer loops [TemporalLoop(OX,56)].
# 2024-02-12 15:50:36,068 - stream.classes.stages.GenerateCNWorkloadHybridStage.run +90 - INFO - ComputationNode(6,): Generated 56 finer nodes.
# 2024-02-12 15:50:36,084 - stream.classes.stages.GenerateCNWorkloadHybridStage.run +89 - INFO - ComputationNode(8,): Outer loops [TemporalLoop(OX,56)].
# 2024-02-12 15:50:36,085 - stream.classes.stages.GenerateCNWorkloadHybridStage.run +90 - INFO - ComputationNode(8,): Generated 56 finer nodes.
# 2024-02-12 15:50:36,100 - stream.classes.stages.GenerateCNWorkloadHybridStage.run +89 - INFO - ComputationNode(10,): Outer loops [TemporalLoop(OX,56)].
# 2024-02-12 15:50:36,100 - stream.classes.stages.GenerateCNWorkloadHybridStage.run +90 - INFO - ComputationNode(10,): Generated 56 finer nodes.
# 2024-02-12 15:50:36,114 - stream.classes.stages.GenerateCNWorkloadHybridStage.run +89 - INFO - ComputationNode(11,): Outer loops [TemporalLoop(OX,56)].
# 2024-02-12 15:50:36,114 - stream.classes.stages.GenerateCNWorkloadHybridStage.run +90 - INFO - ComputationNode(11,): Generated 56 finer nodes.
# 2024-02-12 15:50:36,121 - stream.classes.stages.GenerateCNWorkloadHybridStage.run +89 - INFO - ComputationNode(13,): Outer loops [TemporalLoop(OX,28)].
# 2024-02-12 15:50:36,121 - stream.classes.stages.GenerateCNWorkloadHybridStage.run +90 - INFO - ComputationNode(13,): Generated 28 finer nodes.
# 2024-02-12 15:50:36,129 - stream.classes.stages.GenerateCNWorkloadHybridStage.run +89 - INFO - ComputationNode(16,): Outer loops [TemporalLoop(OX,28)].
# 2024-02-12 15:50:36,129 - stream.classes.stages.GenerateCNWorkloadHybridStage.run +90 - INFO - ComputationNode(16,): Generated 28 finer nodes.
# 2024-02-12 15:50:36,137 - stream.classes.stages.GenerateCNWorkloadHybridStage.run +89 - INFO - ComputationNode(15,): Outer loops [TemporalLoop(OX,28)].
# 2024-02-12 15:50:36,137 - stream.classes.stages.GenerateCNWorkloadHybridStage.run +90 - INFO - ComputationNode(15,): Generated 28 finer nodes.
# 2024-02-12 15:50:36,143 - stream.classes.stages.GenerateCNWorkloadHybridStage.run +89 - INFO - ComputationNode(17,): Outer loops [TemporalLoop(OX,28)].
# 2024-02-12 15:50:36,143 - stream.classes.stages.GenerateCNWorkloadHybridStage.run +90 - INFO - ComputationNode(17,): Generated 28 finer nodes.
# 2024-02-12 15:50:36,151 - stream.classes.stages.GenerateCNWorkloadHybridStage.run +89 - INFO - ComputationNode(19,): Outer loops [TemporalLoop(OX,28)].
# 2024-02-12 15:50:36,152 - stream.classes.stages.GenerateCNWorkloadHybridStage.run +90 - INFO - ComputationNode(19,): Generated 28 finer nodes.
# 2024-02-12 15:50:36,159 - stream.classes.stages.GenerateCNWorkloadHybridStage.run +89 - INFO - ComputationNode(21,): Outer loops [TemporalLoop(OX,28)].
# 2024-02-12 15:50:36,159 - stream.classes.stages.GenerateCNWorkloadHybridStage.run +90 - INFO - ComputationNode(21,): Generated 28 finer nodes.
# 2024-02-12 15:50:36,165 - stream.classes.stages.GenerateCNWorkloadHybridStage.run +89 - INFO - ComputationNode(22,): Outer loops [TemporalLoop(OX,28)].
# 2024-02-12 15:50:36,166 - stream.classes.stages.GenerateCNWorkloadHybridStage.run +90 - INFO - ComputationNode(22,): Generated 28 finer nodes.
# 2024-02-12 15:50:36,170 - stream.classes.stages.GenerateCNWorkloadHybridStage.run +89 - INFO - ComputationNode(24,): Outer loops [TemporalLoop(OX,14)].
# 2024-02-12 15:50:36,171 - stream.classes.stages.GenerateCNWorkloadHybridStage.run +90 - INFO - ComputationNode(24,): Generated 14 finer nodes.
# 2024-02-12 15:50:36,175 - stream.classes.stages.GenerateCNWorkloadHybridStage.run +89 - INFO - ComputationNode(27,): Outer loops [TemporalLoop(OX,14)].
# 2024-02-12 15:50:36,175 - stream.classes.stages.GenerateCNWorkloadHybridStage.run +90 - INFO - ComputationNode(27,): Generated 14 finer nodes.
# 2024-02-12 15:50:36,179 - stream.classes.stages.GenerateCNWorkloadHybridStage.run +89 - INFO - ComputationNode(26,): Outer loops [TemporalLoop(OX,14)].
# 2024-02-12 15:50:36,180 - stream.classes.stages.GenerateCNWorkloadHybridStage.run +90 - INFO - ComputationNode(26,): Generated 14 finer nodes.
# 2024-02-12 15:50:36,184 - stream.classes.stages.GenerateCNWorkloadHybridStage.run +89 - INFO - ComputationNode(28,): Outer loops [TemporalLoop(OX,14)].
# 2024-02-12 15:50:36,184 - stream.classes.stages.GenerateCNWorkloadHybridStage.run +90 - INFO - ComputationNode(28,): Generated 14 finer nodes.
# 2024-02-12 15:50:36,238 - stream.classes.stages.GenerateCNWorkloadHybridStage.run +123 - INFO - Finer graph: DiGraph with 756 nodes and 2384 edges.
# 2024-02-12 15:50:36,242 - stream.classes.stages.IntraCoreMappingStage.run +81 - INFO - Start IntraCoreMappingStage.
# 2024-02-12 15:50:36,242 - stream.classes.stages.IntraCoreMappingStage.get_intra_core_mapping_flow +211 - INFO - Launching intra-core mapping optimization for ComputationNode(0, 0) -> core 0 ...
# 2024-02-12 15:50:36,242 - zigzag.classes.stages.SpatialMappingGeneratorStage.run +127 - INFO - Launching spatial mapping 1/2: {'D1': ('K', 32), 'D2': ('C', 32)}.
# 2024-02-12 15:50:36,243 - zigzag.classes.opt.temporal.loma.engine.run +72 - INFO - Running temporal mapping search engine...
# 2024-02-12 15:50:36,281 - zigzag.classes.stages.SpatialMappingGeneratorStage.run +127 - INFO - Launching spatial mapping 2/2: {'D1': ('G', 32)}.
# 2024-02-12 15:50:36,282 - zigzag.classes.opt.temporal.loma.engine.run +72 - INFO - Running temporal mapping search engine...
# 2024-02-12 15:50:36,548 - stream.classes.stages.IntraCoreMappingStage.get_intra_core_mapping_flow +211 - INFO - Launching intra-core mapping optimization for ComputationNode(2, 0) -> core 4 ...
# 2024-02-12 15:50:36,549 - zigzag.classes.stages.SpatialMappingGeneratorStage.run +127 - INFO - Launching spatial mapping 1/1: {'D1': ('FX', 3), 'D2': ('FY', 3)}.
# 2024-02-12 15:50:36,550 - zigzag.classes.opt.temporal.loma.engine.run +72 - INFO - Running temporal mapping search engine...
# 2024-02-12 15:50:36,552 - stream.classes.stages.IntraCoreMappingStage.get_intra_core_mapping_flow +211 - INFO - Launching intra-core mapping optimization for ComputationNode(3, 0) -> core 0 ...
# 2024-02-12 15:50:36,553 - zigzag.classes.stages.SpatialMappingGeneratorStage.run +127 - INFO - Launching spatial mapping 1/2: {'D1': ('K', 32), 'D2': ('C', 32)}.
# 2024-02-12 15:50:36,553 - zigzag.classes.opt.temporal.loma.engine.run +72 - INFO - Running temporal mapping search engine...
# 2024-02-12 15:50:36,736 - zigzag.classes.stages.SpatialMappingGeneratorStage.run +127 - INFO - Launching spatial mapping 2/2: {'D1': ('G', 32)}.
# 2024-02-12 15:50:36,737 - zigzag.classes.opt.temporal.loma.engine.run +72 - INFO - Running temporal mapping search engine...
# 2024-02-12 15:50:36,921 - stream.classes.stages.IntraCoreMappingStage.get_intra_core_mapping_flow +211 - INFO - Launching intra-core mapping optimization for ComputationNode(5, 0) -> core 0 ...
# 2024-02-12 15:50:36,921 - zigzag.classes.stages.SpatialMappingGeneratorStage.run +127 - INFO - Launching spatial mapping 1/2: {'D1': ('K', 32), 'D2': ('C', 32)}.
# 2024-02-12 15:50:36,922 - zigzag.classes.opt.temporal.loma.engine.run +72 - INFO - Running temporal mapping search engine...
# 2024-02-12 15:50:37,181 - zigzag.classes.stages.SpatialMappingGeneratorStage.run +127 - INFO - Launching spatial mapping 2/2: {'D1': ('G', 32)}.
# 2024-02-12 15:50:37,182 - zigzag.classes.opt.temporal.loma.engine.run +72 - INFO - Running temporal mapping search engine...
# 2024-02-12 15:50:37,365 - stream.classes.stages.IntraCoreMappingStage.get_intra_core_mapping_flow +211 - INFO - Launching intra-core mapping optimization for ComputationNode(6, 0) -> core 5 ...
# 2024-02-12 15:50:37,365 - zigzag.classes.stages.SpatialMappingGeneratorStage.run +127 - INFO - Launching spatial mapping 1/1: {'D1': ('K', 64)}.
# 2024-02-12 15:50:37,366 - zigzag.classes.opt.temporal.loma.engine.run +72 - INFO - Running temporal mapping search engine...
# 2024-02-12 15:50:37,368 - stream.classes.stages.IntraCoreMappingStage.get_intra_core_mapping_flow +211 - INFO - Launching intra-core mapping optimization for ComputationNode(8, 0) -> core 0 ...
# 2024-02-12 15:50:37,368 - zigzag.classes.stages.SpatialMappingGeneratorStage.run +127 - INFO - Launching spatial mapping 1/2: {'D1': ('K', 32), 'D2': ('C', 32)}.
# 2024-02-12 15:50:37,369 - zigzag.classes.opt.temporal.loma.engine.run +72 - INFO - Running temporal mapping search engine...
# 2024-02-12 15:50:37,548 - zigzag.classes.stages.SpatialMappingGeneratorStage.run +127 - INFO - Launching spatial mapping 2/2: {'D1': ('G', 32)}.
# 2024-02-12 15:50:37,548 - zigzag.classes.opt.temporal.loma.engine.run +72 - INFO - Running temporal mapping search engine...
# 2024-02-12 15:50:37,729 - stream.classes.stages.IntraCoreMappingStage.get_intra_core_mapping_flow +211 - INFO - Launching intra-core mapping optimization for ComputationNode(10, 0) -> core 0 ...
# 2024-02-12 15:50:37,730 - zigzag.classes.stages.SpatialMappingGeneratorStage.run +127 - INFO - Launching spatial mapping 1/2: {'D1': ('K', 32), 'D2': ('C', 32)}.
# 2024-02-12 15:50:37,731 - zigzag.classes.opt.temporal.loma.engine.run +72 - INFO - Running temporal mapping search engine...
# 2024-02-12 15:50:37,989 - zigzag.classes.stages.SpatialMappingGeneratorStage.run +127 - INFO - Launching spatial mapping 2/2: {'D1': ('G', 32)}.
# 2024-02-12 15:50:37,990 - zigzag.classes.opt.temporal.loma.engine.run +72 - INFO - Running temporal mapping search engine...
# 2024-02-12 15:50:38,169 - stream.classes.stages.IntraCoreMappingStage.get_intra_core_mapping_flow +211 - INFO - Launching intra-core mapping optimization for ComputationNode(11, 0) -> core 5 ...
# 2024-02-12 15:50:38,170 - zigzag.classes.stages.SpatialMappingGeneratorStage.run +127 - INFO - Launching spatial mapping 1/1: {'D1': ('K', 64)}.
# 2024-02-12 15:50:38,170 - zigzag.classes.opt.temporal.loma.engine.run +72 - INFO - Running temporal mapping search engine...
# 2024-02-12 15:50:38,172 - stream.classes.stages.IntraCoreMappingStage.get_intra_core_mapping_flow +211 - INFO - Launching intra-core mapping optimization for ComputationNode(13, 0) -> core 0 ...
# 2024-02-12 15:50:38,173 - zigzag.classes.stages.SpatialMappingGeneratorStage.run +127 - INFO - Launching spatial mapping 1/2: {'D1': ('K', 32), 'D2': ('C', 32)}.
# 2024-02-12 15:50:38,173 - zigzag.classes.opt.temporal.loma.engine.run +72 - INFO - Running temporal mapping search engine...
# 2024-02-12 15:50:38,353 - zigzag.classes.stages.SpatialMappingGeneratorStage.run +127 - INFO - Launching spatial mapping 2/2: {'D1': ('G', 32)}.
# 2024-02-12 15:50:38,354 - zigzag.classes.opt.temporal.loma.engine.run +72 - INFO - Running temporal mapping search engine...
# 2024-02-12 15:50:38,533 - stream.classes.stages.IntraCoreMappingStage.get_intra_core_mapping_flow +211 - INFO - Launching intra-core mapping optimization for ComputationNode(16, 0) -> core 0 ...
# 2024-02-12 15:50:38,534 - zigzag.classes.stages.SpatialMappingGeneratorStage.run +127 - INFO - Launching spatial mapping 1/2: {'D1': ('K', 32), 'D2': ('C', 32)}.
# 2024-02-12 15:50:38,534 - zigzag.classes.opt.temporal.loma.engine.run +72 - INFO - Running temporal mapping search engine...
# 2024-02-12 15:50:38,543 - zigzag.classes.stages.SpatialMappingGeneratorStage.run +127 - INFO - Launching spatial mapping 2/2: {'D1': ('G', 32)}.
# 2024-02-12 15:50:38,544 - zigzag.classes.opt.temporal.loma.engine.run +72 - INFO - Running temporal mapping search engine...
# 2024-02-12 15:50:38,553 - stream.classes.stages.IntraCoreMappingStage.get_intra_core_mapping_flow +211 - INFO - Launching intra-core mapping optimization for ComputationNode(15, 0) -> core 0 ...
# 2024-02-12 15:50:38,554 - zigzag.classes.stages.SpatialMappingGeneratorStage.run +127 - INFO - Launching spatial mapping 1/2: {'D1': ('K', 32), 'D2': ('C', 32)}.
# 2024-02-12 15:50:38,555 - zigzag.classes.opt.temporal.loma.engine.run +72 - INFO - Running temporal mapping search engine...
# 2024-02-12 15:50:38,808 - zigzag.classes.stages.SpatialMappingGeneratorStage.run +127 - INFO - Launching spatial mapping 2/2: {'D1': ('G', 32)}.
# 2024-02-12 15:50:38,809 - zigzag.classes.opt.temporal.loma.engine.run +72 - INFO - Running temporal mapping search engine...
# 2024-02-12 15:50:38,987 - stream.classes.stages.IntraCoreMappingStage.get_intra_core_mapping_flow +211 - INFO - Launching intra-core mapping optimization for ComputationNode(17, 0) -> core 5 ...
# 2024-02-12 15:50:38,988 - zigzag.classes.stages.SpatialMappingGeneratorStage.run +127 - INFO - Launching spatial mapping 1/1: {'D1': ('K', 64)}.
# 2024-02-12 15:50:38,988 - zigzag.classes.opt.temporal.loma.engine.run +72 - INFO - Running temporal mapping search engine...
# 2024-02-12 15:50:38,990 - stream.classes.stages.IntraCoreMappingStage.get_intra_core_mapping_flow +211 - INFO - Launching intra-core mapping optimization for ComputationNode(19, 0) -> core 0 ...
# 2024-02-12 15:50:38,991 - zigzag.classes.stages.SpatialMappingGeneratorStage.run +127 - INFO - Launching spatial mapping 1/2: {'D1': ('K', 32), 'D2': ('C', 32)}.
# 2024-02-12 15:50:38,992 - zigzag.classes.opt.temporal.loma.engine.run +72 - INFO - Running temporal mapping search engine...
# 2024-02-12 15:50:39,168 - zigzag.classes.stages.SpatialMappingGeneratorStage.run +127 - INFO - Launching spatial mapping 2/2: {'D1': ('G', 32)}.
# 2024-02-12 15:50:39,169 - zigzag.classes.opt.temporal.loma.engine.run +72 - INFO - Running temporal mapping search engine...
# 2024-02-12 15:50:39,426 - stream.classes.stages.IntraCoreMappingStage.get_intra_core_mapping_flow +211 - INFO - Launching intra-core mapping optimization for ComputationNode(21, 0) -> core 0 ...
# 2024-02-12 15:50:39,426 - zigzag.classes.stages.SpatialMappingGeneratorStage.run +127 - INFO - Launching spatial mapping 1/2: {'D1': ('K', 32), 'D2': ('C', 32)}.
# 2024-02-12 15:50:39,427 - zigzag.classes.opt.temporal.loma.engine.run +72 - INFO - Running temporal mapping search engine...
# 2024-02-12 15:50:39,603 - zigzag.classes.stages.SpatialMappingGeneratorStage.run +127 - INFO - Launching spatial mapping 2/2: {'D1': ('G', 32)}.
# 2024-02-12 15:50:39,604 - zigzag.classes.opt.temporal.loma.engine.run +72 - INFO - Running temporal mapping search engine...
# 2024-02-12 15:50:39,782 - stream.classes.stages.IntraCoreMappingStage.get_intra_core_mapping_flow +211 - INFO - Launching intra-core mapping optimization for ComputationNode(22, 0) -> core 5 ...
# 2024-02-12 15:50:39,783 - zigzag.classes.stages.SpatialMappingGeneratorStage.run +127 - INFO - Launching spatial mapping 1/1: {'D1': ('K', 64)}.
# 2024-02-12 15:50:39,784 - zigzag.classes.opt.temporal.loma.engine.run +72 - INFO - Running temporal mapping search engine...
# 2024-02-12 15:50:39,786 - stream.classes.stages.IntraCoreMappingStage.get_intra_core_mapping_flow +211 - INFO - Launching intra-core mapping optimization for ComputationNode(24, 0) -> core 0 ...
# 2024-02-12 15:50:39,786 - zigzag.classes.stages.SpatialMappingGeneratorStage.run +127 - INFO - Launching spatial mapping 1/2: {'D1': ('K', 32), 'D2': ('C', 32)}.
# 2024-02-12 15:50:39,787 - zigzag.classes.opt.temporal.loma.engine.run +72 - INFO - Running temporal mapping search engine...
# 2024-02-12 15:50:39,967 - zigzag.classes.stages.SpatialMappingGeneratorStage.run +127 - INFO - Launching spatial mapping 2/2: {'D1': ('G', 32)}.
# 2024-02-12 15:50:39,967 - zigzag.classes.opt.temporal.loma.engine.run +72 - INFO - Running temporal mapping search engine...
# 2024-02-12 15:50:40,221 - stream.classes.stages.IntraCoreMappingStage.get_intra_core_mapping_flow +211 - INFO - Launching intra-core mapping optimization for ComputationNode(27, 0) -> core 0 ...
# 2024-02-12 15:50:40,221 - zigzag.classes.stages.SpatialMappingGeneratorStage.run +127 - INFO - Launching spatial mapping 1/2: {'D1': ('K', 32), 'D2': ('C', 32)}.
# 2024-02-12 15:50:40,222 - zigzag.classes.opt.temporal.loma.engine.run +72 - INFO - Running temporal mapping search engine...
# 2024-02-12 15:50:40,231 - zigzag.classes.stages.SpatialMappingGeneratorStage.run +127 - INFO - Launching spatial mapping 2/2: {'D1': ('G', 32)}.
# 2024-02-12 15:50:40,232 - zigzag.classes.opt.temporal.loma.engine.run +72 - INFO - Running temporal mapping search engine...
# 2024-02-12 15:50:40,241 - stream.classes.stages.IntraCoreMappingStage.get_intra_core_mapping_flow +211 - INFO - Launching intra-core mapping optimization for ComputationNode(26, 0) -> core 0 ...
# 2024-02-12 15:50:40,242 - zigzag.classes.stages.SpatialMappingGeneratorStage.run +127 - INFO - Launching spatial mapping 1/2: {'D1': ('K', 32), 'D2': ('C', 32)}.
# 2024-02-12 15:50:40,243 - zigzag.classes.opt.temporal.loma.engine.run +72 - INFO - Running temporal mapping search engine...
# 2024-02-12 15:50:40,420 - zigzag.classes.stages.SpatialMappingGeneratorStage.run +127 - INFO - Launching spatial mapping 2/2: {'D1': ('G', 32)}.
# 2024-02-12 15:50:40,421 - zigzag.classes.opt.temporal.loma.engine.run +72 - INFO - Running temporal mapping search engine...
# 2024-02-12 15:50:40,601 - stream.classes.stages.IntraCoreMappingStage.get_intra_core_mapping_flow +211 - INFO - Launching intra-core mapping optimization for ComputationNode(28, 0) -> core 5 ...
# 2024-02-12 15:50:40,602 - zigzag.classes.stages.SpatialMappingGeneratorStage.run +127 - INFO - Launching spatial mapping 1/1: {'D1': ('K', 64)}.
# 2024-02-12 15:50:40,602 - zigzag.classes.opt.temporal.loma.engine.run +72 - INFO - Running temporal mapping search engine...
# 2024-02-12 15:50:40,604 - stream.classes.stages.IntraCoreMappingStage.run +181 - INFO - Finished IntraCoreMappingStage.
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[3], line 38
#      10 _logging.basicConfig(level=_logging_level, format=_logging_format)
#      13 mainstage = MainStage(
#      14     [  # Initializes the MainStage as entry point
#      15         AcceleratorParserStage,  # Parses the accelerator
#    (...)
#      35     ),
#      36 )
# ---> 38 [(scme, _), *_] = mainstage.run()
#      40 plot_timeline_brokenaxes(
#      41     scme,
#      42     False,
#    (...)
#      46     fig_path="/tmp/timeline",
#      47 )
#      49 plot_memory_usage(scme, (0,), (3,), fig_path="/tmp/memory")
#
# File ~/.local/lib/python3.10/site-packages/zigzag/classes/stages/Stage.py:49, in MainStage.run(self)
#      47 def run(self):
#      48     answers = []
# ---> 49     for cme, extra_info in self.list_of_callables[0](
#      50         self.list_of_callables[1:], **self.kwargs
#      51     ).run():
#      52         answers.append((cme, extra_info))
#      53     return answers
#
# File ~/.local/lib/python3.10/site-packages/zigzag/classes/stages/MainInputParserStages.py:21, in AcceleratorParserStage.run(self)
#      19 accelerator = self.accelerator_parser.get_accelerator()
#      20 sub_stage = self.list_of_callables[0](self.list_of_callables[1:], accelerator=accelerator, **self.kwargs)
# ---> 21 for cme, extra_info in sub_stage.run():
#      22     yield cme, extra_info
#
# File ~/.local/lib/python3.10/site-packages/stream/classes/stages/ModelParserStage.py:36, in ONNXModelParserStage.run(self)
#      29 self.kwargs["mapping_path"] = self.mapping_path
#      30 sub_stage = self.list_of_callables[0](
#      31     self.list_of_callables[1:],
#      32     onnx_model=onnx_model,
#      33     workload=workload,
#      34     **self.kwargs,
#      35 )
# ---> 36 for cme, extra_info in sub_stage.run():
#      37     yield cme, extra_info
#
# File ~/.local/lib/python3.10/site-packages/stream/classes/stages/GenerateCNWorkloadHybridStage.py:133, in GenerateCNWorkloadHybridStage.run(self)
#     131     kwargs["scheduling_order"] = self.get_scheduling_order(G)
#     132 sub_stage = self.list_of_callables[0](self.list_of_callables[1:], **kwargs)
# --> 133 for cme, extra_info in sub_stage.run():
#     134     yield cme, extra_info
#     136 yield None, None
#
# File ~/.local/lib/python3.10/site-packages/stream/classes/stages/IntraCoreMappingStage.py:182, in IntraCoreMappingStage.run(self)
#     179 kwargs["node_hw_performances"] = self.node_hw_performances
#     181 logger.info(f"Finished IntraCoreMappingStage.")
# --> 182 sub_stage = self.list_of_callables[0](self.list_of_callables[1:], **kwargs)
#     183 for cme, extra_info in sub_stage.run():
#     184     yield cme, extra_info
#
# File ~/.local/lib/python3.10/site-packages/stream/classes/stages/InterCoreMappingStage.py:109, in InterCoreMappingStage.__init__(self, list_of_callables, workload, accelerator, node_hw_performances, nb_ga_generations, nb_ga_individuals, plot_hof, plot_file_name, plot_full_schedule, plot_data_transfer, operands_to_prefetch, custom_fitness_evaluator, **kwargs)
#     107 # Initialize the fitness evaluator of different core allocations
#     108 if self.custom_fitness_evaluator is not None:
# --> 109     self.fitness_evaluator = self.custom_fitness_evaluator(
#     110         self.workload,
#     111         self.accelerator,
#     112         self.node_hw_performances,
#     113         self.layer_groups_flexible,
#     114         self.scheduling_order,
#     115         self.operands_to_prefetch,
#     116         self.original_workload,
#     117     )
#     118 else:
#     119     self.fitness_evaluator = StandardFitnessEvaluator(
#     120         self.workload,
#     121         self.accelerator,
#    (...)
#     125         self.scheduling_order,
#     126     )
#
# File ~/project/heterogeneous-as-sdf/cyclic-scheduling/cyclic_scheduling_dse/stream_compatibility_layer.py:491, in CyclicFitnessEvaluatorBuilder.__call__(self, workload, accelerator, node_hw_performances, layer_groups_flexible, scheduler_candidate_selection, operands_to_prefetch, original_workload)
#     480 def __call__(
#     481     self,
#     482     workload,
#    (...)
#     488     original_workload,
#     489 ):
#     490     m = { n.id[0]: n.name for n in workload.nodes }
# --> 491     return CyclicFitnessEvaluator(
#     492         sdf_relation=self.sdf_relation,
#     493         optimization_type=self.optimization_type,
#     494         workload=workload,
#     495         original_workload=original_workload,
#     496         node_hw_performances=node_hw_performances,
#     497         layer_groups_flexible=list(map(lambda a: m[a[0]], layer_groups_flexible)),
#     498         accelerator=accelerator
#     499     )
#
# File ~/project/heterogeneous-as-sdf/cyclic-scheduling/cyclic_scheduling_dse/stream_compatibility_layer.py:277, in CyclicFitnessEvaluator.__init__(self, workload, original_workload, node_hw_performances, layer_groups_flexible, accelerator, sdf_relation, optimization_type)
#     267 production_rate = finer_trg.loop_dim_size[self.sdf_relation]
#     268 assert (finer_trg.operand_tensors['O'].size % production_rate) == 0
#     269 cn = WorkloadNode(
#     270     id=node.name,
#     271     conv1d=Convolution1D(
#     272         kernel_size=kernel,
#     273         padding=padding,
#     274         stride=stride,
#     275         production_rate=production_rate,
#     276         output_token_size=finer_trg.operand_tensors['O'].size // production_rate,
# --> 277         input_token_size=finer_trg.operand_tensors['I'].size,
#     278     ),
#     279     n_execution=n_execution,
#     280 )
#     281 nodes[node.name] = cn
#     282 mrsdf.add_node(cn)
#
# KeyError: 'I'

# %%
plot_timeline_brokenaxes(
    scme,
    False,
    section_start_percent=(0,),
    percent_shown=(100,),
    plot_data_transfer=True,
    fig_path="/tmp/timeline",
)
plot_memory_usage(scme, (0,), (100,), fig_path="/tmp/memory")
# Out:
# 2024-02-01 13:20:12,949 - stream.visualization.schedule.plot_timeline_brokenaxes +65 - INFO - Plotting...
# 2024-02-01 13:20:17,837 - stream.visualization.schedule.plot_timeline_brokenaxes +319 - INFO - Plotted schedule timeline to /tmp/timeline
# Saved memory usage fig to /tmp/memory

# %%
import logging as _logging

_logging_level = _logging.INFO
_logging_format = (
    "%(asctime)s - %(name)s.%(funcName)s +%(lineno)s - %(levelname)s - %(message)s"
)
_logging.basicConfig(level=_logging_level, format=_logging_format)


mainstage = MainStage(
    [  # Initializes the MainStage as entry point
        AcceleratorParserStage,  # Parses the accelerator
        StreamONNXModelParserStage,  # Parses the ONNX Model into the workload
        GenerateCNWorkloadHybridStage,
        IntraCoreMappingStage,
        InterCoreMappingStage,
    ],
    accelerator="architecture.eyeriss_tpu",  # required by AcceleratorParserStage
    workload_path="./problems/fsrcnn.onnx",  # required by ModelParserStage
    mapping_path="mapping.super_resolution_mapping",
    cn_define_mode=1,
    hint_loops=[("OX", "all")],
    loma_lpf_limit=2,
    nb_ga_generations = 25,
    nb_ga_individuals = 25,
    plot_hof=True,
    plot_file_name='plot.png',
    scheduler_candidate_selection = 'latency',
    operands_to_prefetch = [],
    custom_fitness_evaluator=CyclicFitnessEvaluatorBuilder(
        sdf_relation="OX",
        pipelining=10,
    ),
)

[(scme, _), *_] = mainstage.run()

plot_timeline_brokenaxes(
    scme,
    False,
    section_start_percent=(0,),
    percent_shown=(3,),
    plot_data_transfer=True,
    fig_path="/tmp/timeline",
)

plot_memory_usage(scme, (0,), (3,), fig_path="/tmp/memory")
# Out:
# HI...False
# CommunicationLink(Core(2), Any, bw=64)
# Saved memory usage fig to /tmp/memory

# %%
plot_timeline_brokenaxes(
    scme,
    False,
    section_start_percent=(0,),
    percent_shown=(100,),
    plot_data_transfer=True,
    fig_path="/tmp/timeline",
)
# Out:
# 2024-01-31 10:17:42,954 - stream.visualization.schedule.plot_timeline_brokenaxes +65 - INFO - Plotting...
# 2024-01-31 10:18:34,507 - stream.visualization.schedule.plot_timeline_brokenaxes +319 - INFO - Plotted schedule timeline to /tmp/timeline

# %%
scme.cyclic_scheduling.plot_with_processors()
# Out:
# CyclicSchedulingPlot(data='{"problem": {"actors": [{"name": "/conv1/Conv(0)", "execution_time": 28721, "proces…

# %%
scme.cyclic_scheduling.plot_asap()
# Out:
# CyclicSchedulingPlot(data='{"problem": {"actors": [{"name": "/conv1/Conv(0)", "execution_time": 28721, "proces…

# %%
plot_timeline_brokenaxes(
    scme,
    False,
    section_start_percent=(0,),
    percent_shown=(100,),
    plot_data_transfer=True,
    fig_path="/tmp/timeline",
)

plot_memory_usage(scme, (0,), (100,), fig_path="/tmp/memory")

# %%
plot_timeline_brokenaxes(
    scme,
    False,
    section_start_percent=(0,),
    percent_shown=(3,),
    plot_data_transfer=True,
    fig_path="/tmp/timeline",
)

plot_memory_usage(scme, (0,), (3,), fig_path="/tmp/memory")
# Out:
# 2024-01-31 10:54:37,237 - stream.visualization.schedule.plot_timeline_brokenaxes +65 - INFO - Plotting...
# 2024-01-31 10:54:38,872 - stream.visualization.schedule.plot_timeline_brokenaxes +319 - INFO - Plotted schedule timeline to /tmp/timeline
# Saved memory usage fig to /tmp/memory

# %%
plot_memory_usage(scme, (0,), (100,), fig_path="/tmp/memory")
# Out:
# Saved memory usage fig to /tmp/memory

# %%
mainstage = MainStage(
    [  # Initializes the MainStage as entry point
        AcceleratorParserStage,  # Parses the accelerator
        StreamONNXModelParserStage,  # Parses the ONNX Model into the workload
        # UserDefinedModelParserStage,  # Parses the user-defined Model into the workload
        GenerateCNWorkloadHybridStage,
        IntraCoreMappingStage,
        InterCoreMappingStage,
    ],
    accelerator="architecture.eyeriss_like_dual_core",  # required by AcceleratorParserStage
    workload_path="./problems/resnet18_3_convolutions.onnx",  # required by ModelParserStage
    mapping_path="mapping.resnet_mapping",
    loma_lpf_limit=6,  # required by LomaStage
    nb_ga_individuals=25,  # number of individuals in each genetic algorithm generation
    nb_ga_generations=25,  # number of genetic algorithm generations
    node_hw_performances_path="./core-layer-mapping.pickle",  # saved node_hw_performances to skip re-computation
    plot_hof=True,  # Save schedule and memory usage plot of each individual in the Genetic Algorithm hall of fame
    plot_file_name="plot",
    plot_full_schedule=False,
    plot_data_transfer=False,
    cn_define_mode=1,
    hint_loops=[("OX", "all")],
    scheduler_candidate_selection="memory",
    operands_to_prefetch=[],
)

[scme, *_], _ = mainstage.run()

# %%
scme.cy

# %%
stream_scme = scme

# %%
plot_timeline_brokenaxes(
    scme,
    False,
    section_start_percent=(0,),
    percent_shown=(100,),
    plot_data_transfer=True,
    fig_path="/tmp/timeline",
)

plot_memory_usage(scme, (0,), (100,), fig_path="/tmp/memory")

# %%
for k, item in node_performances.items():
    print(f"Layer {k.id[0]}")
    for op in k.operand_tensors.keys():
        tensor = k.operand_tensors[op]
        operand_precision = k.operand_precision[op]
        print(f"\t{op}: size={tensor.size} operand-size={operand_precision} loops= {','.join(map(lambda x: f'{x[0]}:[{x[1][0]}..{x[1][1]})', zip(tensor.loop_dimensions, tensor.loop_ranges)))}")
    print("\n\t\tLatency\tEnergy")
    for core, cme in item.items():
        print(f"\tCore {core.id}:\t{cme.latency_total1}\t{cme.energy_total}")
    print()

# %%
import graphviz
from architecture.tpu_like_dual_core import cores_graph

dot = graphviz.Digraph()
for core in cores_graph.nodes():
    dot.node(str(core.id), f"Core {core.id}" if core.id != 2 else "DRAM")

for (source, target, channel) in cores_graph.edges.data():
    dot.edge(str(source.id), str(target.id), label=f"bw={channel['cl'].bandwidth}")
    
dot

# %%
from cyclic_scheduling import CyclicSchedulingProblem
from math import ceil

problem = CyclicSchedulingProblem()

problem.add_processor('Core 0')
problem.add_processor('Core 1')
problem.add_processor('Core 0 -> Core 1')
problem.add_processor('DRAM <-> Any')
problem.add_processor('Core 1 -> Core 0')

problem.add_actor('lᵢ', ceil(21760/64), 'DRAM <-> Any', '#8000ff') # Loading of input 
problem.add_actor('c₀', 27050, 'Core 0', '#8000ff') # Layer 0
problem.add_actor('t₀₁', ceil(241920/64), 'Core 0 -> Core 1', '#8000ff') # Transfer from Core 0 to Core 1
problem.add_actor('c₁', 1317, 'Core 1', '#376bf5') # Layer 1
problem.add_actor('t₁₂', ceil(51840/64), 'Core 1 -> Core 0', '#376bf5')
problem.add_actor('c₂', 5012, 'Core 0', '#12c6e3') # Layer 2 
problem.add_actor('t₂₃', ceil(51840/64), 'Core 0 -> Core 1', '#12c6e3')
problem.add_actor('c₃', 5012, 'Core 1', '#5bf9c9') # Layer 3 
problem.add_actor('c₄', 7312, 'Core 1', '#a2f69d') # Layer 4 
problem.add_actor('c₅', 5012, 'Core 1', '#eac66e') # Layer 5
problem.add_actor('t₅₆', ceil(51840/64), 'Core 1 -> Core 0', '#eac66e')
problem.add_actor('c₆', 1131, 'Core 0', '#fc6c37') # Layer 6
problem.add_actor('t₆₇', ceil(241920/64), 'Core 0 -> Core 1', '#fc6c37')
problem.add_actor('c₇', 9783, 'Core 1', '#fd0000') # Layer 7 
problem.add_actor('sₒ', ceil(69120/64), 'DRAM <-> Any', '#fd0000') # Store of output


problem.add_channel('lᵢ', 'c₀')
problem.add_channel('c₀', 't₀₁')
problem.add_channel('t₀₁', 'c₁')
problem.add_channel('c₁', 't₁₂')
problem.add_channel('t₁₂', 'c₂', -1)
problem.add_channel('c₂', 't₂₃')
problem.add_channel('t₂₃', 'c₃', -1)
problem.add_channel('c₃', 'c₄', -1)
problem.add_channel('c₄', 'c₅', -1)
problem.add_channel('c₅', 't₅₆')
problem.add_channel('t₅₆', 'c₆')
problem.add_channel('c₆', 't₆₇')
problem.add_channel('t₆₇', 'c₇', -1)
problem.add_channel('c₇', 'sₒ')
problem

# %%
solution = problem.solve()
solution.plot_with_processors()

# %%
problem.solution(relaxed=True)

# %%
import numpy as np

sol = solution.solution(relaxed=True)
cycle_time = sol.cycle_time
start_time = np.array(sol.t)
end_time = start_time + np.fromiter(map(lambda a: a.execution_time, problem.actors), int)

# %%
cycle_time

# %%
start_time

# %%
end_time

# %%
memory_cost = np.array([
    # start core 0, end core 0, start core 1, end core 1
    [ 21760,      0,      0,      0], # Load Layer 0 I Tensor (DRAM <-> Any)
    [241920, -21760,      0,      0], # Layer 0 (Core 0)
    [     0,-241920, 241920,      0], # Transfer Layer 0 -> Layer 1 (Core 0 -> Core 1)
    [     0,      0,  51840,-241920], # Layer 1 (Core 1)
    [ 51840,      0,      0, -51840], # Transfer Layer 1 -> Layer 2 (Core 1 -> Core 0)
    [ 51840,  -51840,     0,      0], # Layer 2 (Core 0)
    [     0,  -51840, 51840,      0], # Transfer Layer 2 -> Layer 3 (Core 0 -> Core 1)
    [     0,       0, 51840, -51840], # Layer 3 (Core 1)
    [     0,       0, 51840, -51840], # Layer 4 (Core 1)
    [     0,       0, 51840, -51840], # Layer 5 (Core 1)
    [ 51840,       0,     0, -51840], # Transfer Layer 5 -> Layer 6 (Core 1 -> Core 0)
    [241920,  -51840,     0,      0], # Layer 6 (Core 0)
    [     0, -241920,241920,      0], # Transfer Layer 6 -> Layer 7 (Core 0 -> Core 1)
    [     0,       0, 69120,-241920], # Layer 7 (Core 1)
    [     0,       0,     0, -69120]  # Store Layer 7 O Tensor (DRAM <-> Any)
])

# %%
core0_start, core0_end, core1_start, core1_end = memory_cost.T

# %%
from math import ceil
sample = lambda sample_time, first_fire_time, cost: np.sum(cost*np.maximum(np.ceil((sample_time - first_fire_time)/cycle_time), 0))

# %%
sample_core0 = np.vectorize(lambda t: sample(t, start_time, core0_start) + sample(t, end_time, core0_end))
sample_core1 = np.vectorize(lambda t: sample(t, start_time, core1_start) + sample(t, end_time, core1_end))

# %%
def get_change_points(events, cycle_time, end_time):
    from math import ceil
    from heapq import heapify, heappop, heappush
    events = list(events)
    heapify(events)
    while True:
        t = heappop(events)
        if t > end_time:
            break
        yield t
        heappush(events, t + cycle_time)

# %%
sample_times =  np.fromiter(get_change_points(list(start_time) + list(end_time), cycle_time, 400000), int)

# %%
import matplotlib.pyplot as plt

fig = plt.gcf()
fig.set_size_inches(18.5, 3.5)
plt.title("core 0 memory")
plt.xlabel("clock cycle")
plt.ylabel("kB")
y = sample_core0(sample_times)/(8*1024)
plt.step(sample_times, y)
max_y = np.max(y)
plt.axhline(y=max_y, color='r', linestyle='--')
plt.text(0, max_y, f"{max_y} kB")

# %%
import matplotlib.pyplot as plt

fig = plt.gcf()
fig.set_size_inches(18.5, 3.5)
plt.title("core 1 memory")
plt.xlabel("clock cycle")
plt.ylabel("kB")
y = sample_core1(sample_times)/(8*1024)
plt.step(sample_times, y)
max_y = np.max(y)
plt.axhline(y=max_y, color='r', linestyle='--')
plt.text(0, max_y, f"{max_y} kB")

# %%
import sdf_expander
help(sdf_expander)
